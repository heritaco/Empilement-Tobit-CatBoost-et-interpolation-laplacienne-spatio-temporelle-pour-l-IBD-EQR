# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
# read parquet preds/IBD_preds_all_regions.parquet
df = pd.read_parquet("preds/IBD_preds_all_regions.parquet") 
df.head()
# Out:
#    TotalAbundance_SamplingOperation  Achat02   Achco02     Achde03   Acheu01  \
# 0                               400  2.50000       NaN         NaN       NaN
# 1                               404  9.90099       NaN         NaN       NaN
# 2                               400      NaN       NaN   62.500000       NaN
# 3                               397      NaN  2.518892  269.521411  2.518892
# 4                               410      NaN       NaN  290.243902       NaN
#
#    Achge01  Achla02  Achla04     Achmi02  Achmi03   Achpy01  Achri01  Achst03  \
# 0      NaN      NaN      NaN   47.500000      NaN       NaN      NaN      2.5
# 1      NaN      NaN      NaN   89.108911      NaN  4.950495      NaN      NaN
# 2      NaN      5.0      NaN   25.000000      NaN       NaN      NaN      NaN
# 3      NaN      NaN      NaN   68.010076      NaN       NaN      NaN      NaN
# 4      NaN      NaN      NaN  109.756098      NaN       NaN      NaN      NaN
#
# ...

# %%
# plot IBD_pred
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))
plt.hist(df['IBD_pred'], bins=30)
plt.show()

# %%
import mapping

# %%
ranges = mapping.add_tol_to_ranges(tol=2)
ranges
# Out:
#         HERlvl1Name IBD_EQR_Status  IBD_min  IBD_max  IBD_mid
# 0    ALPES INTERNES            Bad   -2.000    9.800     9.30
# 1    ALPES INTERNES           Poor    9.800   13.225    10.30
# 2    ALPES INTERNES       Moderate   13.225   17.025    16.15
# 3    ALPES INTERNES           Good   17.025   18.725    17.90
# 4    ALPES INTERNES           High   18.725   22.000    19.55
# ..              ...            ...      ...      ...      ...
# 105          VOSGES            Bad   -2.000    9.550     7.90
# 106          VOSGES           Poor    9.550   12.775    11.20
# 107          VOSGES       Moderate   12.775   15.700    14.35
# 108          VOSGES           Good   15.700   18.075    17.05
# 109          VOSGES           High   18.075   22.000    19.10
#
# [110 rows x 5 columns]

# %%
# df = df.set_index('SamplingOperations_code')
preds = df['IBD_pred']
preds
# Out:
# 0       14.479493
# 1       15.194359
# 2       13.903476
# 3       14.921369
# 4       15.851655
#           ...
# 5658    19.901358
# 5659    19.203143
# 5660    17.942659
# 5661    19.735215
# 5662    20.012444
# Name: IBD_pred, Length: 5663, dtype: float64

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Necesitas un yhat que sea asi para que ya te regrese el status

# %%
send_predictions = mapping.get_results(df, ranges, output_file="IBD_EQR_Status_predictions_catboost.csv")
send_predictions
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18964\2047823365.py in ?()
# ----> 1 send_predictions = mapping.get_results(df, ranges, output_file="IBD_EQR_Status_predictions_catboost.csv")
#       2 send_predictions
#
# c:\Users\herie\OneDrive - Fundacion Universidad de las Americas Puebla\Proyectos\En Proceso\Clasificacion-de-Calidad-del-Agua-IBD-EQR\notebooks\04 random forest\mapping.py in ?(yhat, ranges, output_file)
#      65 def get_results(yhat, ranges, output_file="IBD_EQR_Status_predictions_5663.csv") -> pd.Series:
# ---> 66     yhat2 = to_status(yhat, ranges)
#      67     send_predictions = yhat2['IBD_EQR_Status_Predicted']
#      68     send_predictions = send_predictions.to_frame()
#      69     send_predictions = send_predictions.rename(columns={'IBD_EQR_Status_Predicted': 'IBD_EQR_Status'})
#
# ...
