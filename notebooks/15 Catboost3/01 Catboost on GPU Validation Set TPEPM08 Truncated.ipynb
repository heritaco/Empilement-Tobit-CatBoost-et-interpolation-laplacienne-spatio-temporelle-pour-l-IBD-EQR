# %%
import pandas as pd

# %%
a=3

# %%
import numpy as np
import os

# before: path = "../../data/processed/"
path = "data/processed"
dfs = {}

# read 03_CLEAN_COMPLETE_DF.parquet
df1 = pd.read_parquet(os.path.join(path, "taxones_pressure_epm_train.parquet"))
df2 = pd.read_parquet(os.path.join(path, "taxones_pressure_epm_predict.parquet"))
df = pd.concat([df1, df2], ignore_index=True)
df1 = None
df2 = None
# keep the odds from the dataframe

# change unassessed values to NaN
df = df.replace("Unassessed", np.nan)
df = df.replace("None", np.nan)

# index SamplingOperations_code
# df = df.set_index('SamplingOperations_code')


# sort by Date_SamplingOperation
df = df.sort_values(by='Date_SamplingOperation')

# df = df[['CodeSite_SamplingOperations_x', 'Date_SamplingOperation', 'IBD', 'Longitude_Lambert93', 'Latitude_Lambert93']]
# DROP HERlvl2Code	Altitude Longitude_Lambert93	Latitude_Lambert93	Watershed	CodeDepartement	HERlvl1Code
# df = df.drop(columns=['HERlvl2Code', 'HERlvl2Name', 'HERlvl1Name', 'Altitude','Longitude_Lambert93','Latitude_Lambert93','Watershed','CodeDepartement', 'Date_SamplingOperation'])

# %%
# replace dateSamplingOperation for interger representing the date as YYYYMMDD
# convert to datetime first
df['Date_SamplingOperation'] = pd.to_datetime(df['Date_SamplingOperation'], format='%Y-%m-%d')
# then convert to integer YYYYMMDD
df['Date_SamplingOperation'] = df['Date_SamplingOperation'].dt.strftime('%Y%m%d').astype(int)

pd.set_option('display.max_columns', None)
df
# Out:
#       SamplingOperations_code CodeSite_SamplingOperations_x  \
# 2703       S02115200_20070702                     S02115200
# 33984      S05218450_20070709                     S05218450
# 33929      S05217350_20070709                     S05217350
# 48228      S05235850_20070709                     S05235850
# 35408      S05234290_20070709                     S05234290
# ...                       ...                           ...
# 42720      S06580577_20230907                     S06580577
# 35760      S06001284_20230907                     S06001284
# 35783      S06001533_20230907                     S06001533
# 38878      S06137040_20231011                     S06137040
# 38873      S06137014_20231011                     S06137014
#
#        Date_SamplingOperation  TotalAbundance_SamplingOperation  Achaa01  \
# 2703                 20070702                               400      NaN
# 33984                20070709                               400      NaN
# 33929                20070709                               400      NaN
# 48228                20070709                               400      NaN
# 35408                20070709                               400      NaN
# ...                       ...                               ...      ...
# 42720                20230907                               426      NaN
# 35760                20230907                               421      NaN
# 35783                20230907                               401      NaN
# 38878                20231011                               400      NaN
# 38873                20231011                               405      NaN
#
#        Achac01  Achaf01  Achaf02  Achal01  Acham01  Achan01  Achat01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN     12.5      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      2.5      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      7.5      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#          Achat02  Achat03  Achba01  Achbi01  Achbi02  Achbr01  Achca01  \
# 2703         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929   5.000000      NaN      NaN      NaN      NaN      NaN      NaN
# 48228  42.500000      NaN      NaN      NaN      NaN      NaN      NaN
# 35408  20.000000      NaN      NaN      NaN      NaN      NaN      NaN
# ...          ...      ...      ...      ...      ...      ...      ...
# 42720   4.694836      NaN      NaN      NaN      NaN      NaN      NaN
# 35760        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783  14.962594      NaN      NaN      NaN      NaN      NaN      NaN
# 38878  42.500000      NaN      NaN      NaN      NaN      NaN      NaN
# 38873  69.135802      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achca02  Achca03  Achca04  Achch01  Achcl01  Achco01  Achco02  Achco03  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN     12.5      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achco04  Achcr01  Achcy01  Achda01  Achda02  Achde01  Achde02  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      2.5      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#          Achde03  Achdi01  Achdi02  Achdr01  Achel01  Achen01    Acheu01  \
# 2703         NaN      NaN      NaN      NaN      NaN      NaN   2.500000
# 33984        NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 33929        NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 48228        NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 35408        NaN      NaN      NaN      NaN      NaN      NaN  42.500000
# ...          ...      ...      ...      ...      ...      ...        ...
# 42720        NaN      NaN      NaN      NaN      NaN      NaN   7.042254
# 35760        NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 35783        NaN      NaN      NaN      NaN      NaN      NaN   2.493766
# 38878  40.000000      NaN      NaN      NaN      NaN      NaN        NaN
# 38873   9.876543      NaN      NaN      NaN      NaN      NaN        NaN
#
#        Achex01  Achex02  Achex03  Achfl01  Achfr01  Achfu01  Achge01  Achgr01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achgr02  Achgr03  Achha01  Achhe01  Achhi01  Achho01  Achho02  Achho03  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achhu01  Achim01  Achim02  Achim03  Achin01  Achin02  Achja01  Achja02  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achjo01  Achko01  Achkr01  Achkr02  Achkr03  Achkr04  Achku01  Achla01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#          Achla02  Achla03    Achla04  Achla05  Achla06  Achle01  Achle02  \
# 2703   37.500000      NaN   5.000000      NaN      NaN      NaN      NaN
# 33984        NaN      NaN        NaN      NaN      NaN      NaN      NaN
# 33929        NaN      NaN        NaN      NaN      NaN      NaN      NaN
# 48228        NaN      NaN        NaN      NaN      NaN      NaN      NaN
# 35408  22.500000      NaN   5.000000      NaN      NaN      NaN      NaN
# ...          ...      ...        ...      ...      ...      ...      ...
# 42720  18.779343      NaN  21.126761      NaN      NaN      NaN      NaN
# 35760   4.750594      NaN        NaN      NaN      NaN      NaN      NaN
# 35783   2.493766      NaN   2.493766      NaN      NaN      NaN      NaN
# 38878        NaN      NaN        NaN      NaN      NaN      NaN      NaN
# 38873        NaN      NaN        NaN      NaN      NaN      NaN      NaN
#
#        Achli01  Achli02     Achli03  Achli04  Achlo01  Achlu01  Achlu02  \
# 2703       NaN      NaN    2.500000      NaN      NaN      NaN      NaN
# 33984      NaN      NaN   15.000000      NaN      NaN      NaN      NaN
# 33929      NaN      NaN    7.500000      NaN      NaN      NaN      NaN
# 48228      NaN      NaN  215.000000      NaN      NaN      NaN      NaN
# 35408      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# ...        ...      ...         ...      ...      ...      ...      ...
# 42720      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN    7.407407      NaN      NaN      NaN      NaN
#
#        Achma01  Achmi01     Achmi02    Achmi03  Achmo01  Achmo02  Achna01  \
# 2703       NaN      NaN   55.000000        NaN      NaN      NaN      NaN
# 33984      NaN      NaN  612.500000        NaN      NaN      NaN      NaN
# 33929      NaN      NaN  162.500000        NaN      NaN      NaN      NaN
# 48228      NaN      NaN  237.500000        NaN      NaN      NaN      NaN
# 35408      NaN      NaN  365.000000        NaN      NaN      NaN      NaN
# ...        ...      ...         ...        ...      ...      ...      ...
# 42720      NaN      NaN         NaN  32.863850      NaN      NaN      NaN
# 35760      NaN      NaN         NaN   4.750594      NaN      NaN      NaN
# 35783      NaN      NaN         NaN  24.937656      NaN      NaN      NaN
# 38878      NaN      NaN  240.000000  20.000000      NaN      NaN      NaN
# 38873      NaN      NaN  308.641975        NaN      NaN      NaN      NaN
#
#        Achna02  Achne01  Achni01  Achno01  Achob01  Achpa01  Achpe01  Achpe02  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achpf01  Achpl01  Achpo01  Achpr01  Achpr02  Achps01  Achps02  Achps03  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achps04  Achpu01     Achpy01  Achre01  Achri01  Achro01  Achro02  \
# 2703       NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN  287.500000      NaN      NaN      NaN      NaN
# 33929      NaN      NaN  775.000000      NaN      NaN      NaN      NaN
# 48228      NaN      NaN   40.000000      NaN      NaN      NaN      NaN
# 35408      NaN      NaN   10.000000      NaN      NaN      NaN      NaN
# ...        ...      ...         ...      ...      ...      ...      ...
# 42720      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN   40.380048      NaN      NaN      NaN      NaN
# 35783      NaN      NaN   19.950125      NaN      NaN      NaN      NaN
# 38878      NaN      NaN  307.500000      NaN      NaN      NaN      NaN
# 38873      NaN      NaN  444.444444      NaN      NaN      NaN      NaN
#
#        Achro03  Achro04  Achru01  Achru02  Achsa01  Achsc01  Achse01  Achse02  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achsi01  Achst01  Achst02  Achst03  Achst04    Achsu01  Achsu02  \
# 2703       NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN  10.000000      NaN
# 35408      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# ...        ...      ...      ...      ...      ...        ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN   4.987531      NaN
# 38878      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN        NaN      NaN
#
#        Achsu03  Achsu04  Achsu05  Achsu06  Achsu07  Achte01  Achth01  Achtr01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achtr02  Achtr03  Achtu01  Achzh01  Achzi01  Actde01  Actno01  Actro01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Actse01  Actsp01  Actsu01  Actvu01  Adlaq01  Adlba01  Adlbr01  Adlbr02  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Adlmi01  Adlmu01  Adlmu02  Adlpa01  Adlsu01  Afrre01  Ampae01  Ampaf01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      5.0      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Ampal01  Ampat01  Ampbi01  Ampbu01  Ampco01  Ampcu01  Ampde01  Ampdi01  \
# 2703       NaN      7.5      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Ampdi02  Ampdu01  Ampei01  Ampex01  Ampfo01  Ampfo02  Amphe01  Amphi01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Ampin01    Ampin02  Ampli01  Ampma01  Ampme01  Ampmi01  Ampmi02  \
# 2703       NaN        NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN        NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN        NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN        NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN        NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...        ...      ...      ...      ...      ...      ...
# 42720      NaN   4.694836      NaN      NaN      NaN      NaN      NaN
# 35760      NaN  61.757720      NaN      NaN      NaN      NaN      NaN
# 35783      NaN   4.987531      NaN      NaN      NaN      NaN      NaN
# 38878      NaN        NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN        NaN      NaN      NaN      NaN      NaN      NaN
#
#        Ampmo01  Ampne01  Ampne02  Ampno01  Ampol01  Ampov01  Amppa01  Amppe01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#           Amppe02  Amppo01  Amppo02  Amppr01  Ampps01  Ampri01  Ampst01  \
# 2703   110.000000      NaN      NaN      NaN      NaN      NaN      NaN
# 33984         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929         NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228    2.500000      NaN      NaN      NaN      NaN      NaN      NaN
# 35408   32.500000      NaN      NaN      NaN      NaN      NaN      NaN
# ...           ...      ...      ...      ...      ...      ...      ...
# 42720  366.197183      NaN      NaN      NaN      NaN      NaN      NaN
# 35760  285.035629      NaN      NaN      NaN      NaN      NaN      NaN
# 35783   64.837905      NaN      NaN      NaN      NaN      NaN      NaN
# 38878   17.500000      NaN      NaN      NaN      NaN      NaN      NaN
# 38873   17.283951      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Ampst02  Ampsu01  Ampsu02  Ampsu03  Ampsu04  Amptu01  Ampve01  Ampve02  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      7.5      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Ampvi01  Anaba01  Anemi01  Anetu01  Anoeu01  Anoga01  Anoin01  Anosp01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Astfo01  Aulal01  Aulam01  Aulbr01  Aulcr01  Aulcr02  Auldi01  Aulgr01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Aulis01  Aulit01  Aulli01  Aulni01  Aulpa01  Aulps01  Aulps02  Aulsu01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Aulsu02  Aulte01  Aulva01  Azpno01  Bacci01  Bacpa01  Bacul01  Berru01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Bible01  Birbi01  Brabr01  Braca01  Brali01  Brane01  Brane02  Brapr01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Braps01  Breke01   Calae01  Calae02  Calal01  Calau01  Calba01  \
# 2703       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN       NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN       NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN       NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN       NaN      NaN      NaN      NaN      NaN
# ...        ...      ...       ...      ...      ...      ...      ...
# 42720      NaN      NaN       NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN  9.501188      NaN      NaN      NaN      NaN
# 35783      NaN      NaN       NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN       NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN       NaN      NaN      NaN      NaN      NaN
#
#        Calbi01  Calfa01  Calfo01  Calfo02  Calhy01  Calla01  Calla02  Calla03  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Calle01  Calmi01  Calpa01  Calpu01  Calsc01  Calsi01  Caltr01  Calve01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Calwe01  Camcy01  Camhi01  Capcr01  Catad01  Cavpa01  Cenre01  Cergr01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Chaal01  Chabe01  Chafa01  Chamu01  Chare01  Charh01  Chasc01  Chath01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Clico01  Cliin01  Cocbr01  Cocca01  Coccl01  Cocco01  Cocde01  Cocdi01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cocdi02     Coceu01  Cocgr01  Cochu01  Cochu02  Cocin01  Cocla01  \
# 2703       NaN   17.500000      NaN      NaN      NaN      NaN      NaN
# 33984      NaN         NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN         NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN    7.500000      NaN      NaN      NaN      NaN      NaN
# 35408      NaN   55.000000      NaN      NaN      NaN      NaN      NaN
# ...        ...         ...      ...      ...      ...      ...      ...
# 42720      NaN  284.037559      NaN      NaN      NaN      NaN      NaN
# 35760      NaN   21.377672      NaN      NaN      NaN      NaN      NaN
# 35783      NaN  319.201995      NaN      NaN      NaN      NaN      NaN
# 38878      NaN  120.000000      NaN      NaN      NaN      NaN      NaN
# 38873      NaN   17.283951      NaN      NaN      NaN      NaN      NaN
#
#        Cocle01   Cocli01  Cocme01  Cocne01  Cocne02  Cocne03  Cocpa01  \
# 2703       NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN  2.500000      NaN      NaN      NaN      NaN      NaN
# 48228      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN       NaN      NaN      NaN      7.5      NaN      NaN
# ...        ...       ...      ...      ...      ...      ...      ...
# 42720      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN  5.000000      NaN      NaN      5.0      NaN      NaN
# 38873      NaN  4.938272      NaN      NaN      NaN      NaN      NaN
#
#           Cocpe01    Cocpl01  Cocps01  Cocps02  Cocre01  Cocro01  Cocsc01  \
# 2703   105.000000        NaN      NaN      NaN      NaN      NaN      NaN
# 33984         NaN        NaN      NaN      NaN      NaN      NaN      NaN
# 33929         NaN   2.500000      NaN      NaN      NaN      NaN      NaN
# 48228         NaN        NaN      NaN      NaN      NaN      NaN      NaN
# 35408         NaN        NaN      NaN      NaN      NaN      NaN      NaN
# ...           ...        ...      ...      ...      ...      ...      ...
# 42720         NaN        NaN      NaN      NaN      NaN      NaN      NaN
# 35760         NaN        NaN      NaN      NaN      NaN      NaN      NaN
# 35783    2.493766  12.468828      NaN      NaN      NaN      NaN      NaN
# 38878         NaN  10.000000      NaN      NaN      NaN      NaN      NaN
# 38873         NaN        NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cocse01  Cocsu01  Conwe01  Cosco01  Cosla01  Cosla02  Craac01  Craac02  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Craha01  Crari01  Crasu01  Crasv01  Cravi01  Crazi01  Creru01  Creth01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Ctepu01  Cycat01  Cycbo01  Cycco01  Cyccy01  Cycde01  Cycde02  Cycdi01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#         Cycdu01  Cycex01  Cycgl01  Cycir01  Cyckr01  Cycku01  Cycme01  \
# 2703        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...         ...      ...      ...      ...      ...      ...      ...
# 42720       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873  2.469136      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cycme02  Cycmi01  Cycop01  Cycpl01  Cycpl02  Cycps01  Cycsc01  Cycsc02  \
# 2703      15.0      NaN      NaN      NaN      NaN     20.0      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cycst01  Cycst02  Cycst03  Cycst04  Cycsu01  Cycth01  Cycwo01  Cylgr01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cymaf01  Cymaf02  Cymal01  Cymal02  Cymam01  Cyman01  Cyman02  Cyman03  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38878      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 38873      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cyman04  Cymap01  Cymas01  Cymbe01  Cymbi01  Cymbr01  Cymbu01  Cymci01  \
# 2703       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33984      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 33929      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35408      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 42720      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35760      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 35783      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_1470  Mean90Days_1473  Mean90Days_1476  Mean90Days_1480  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_1486  Mean90Days_1490  Mean90Days_1493  Mean90Days_1506  \
# 2703               NaN              NaN              7.0              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_1517  Mean90Days_1522  Mean90Days_1524  Mean90Days_1537  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_1548  Mean90Days_1549  Mean90Days_1586  Mean90Days_1591  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_1592  Mean90Days_1593  Mean90Days_1621  Mean90Days_1622  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_1623  Mean90Days_1629  Mean90Days_1630  Mean90Days_1642  \
# 2703               NaN             0.04             0.04              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_1643  Mean90Days_1644  Mean90Days_1645  Mean90Days_1646  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_1647  Mean90Days_1648  Mean90Days_1649  Mean90Days_1652  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_1666  Mean90Days_1669  Mean90Days_1688  Mean90Days_1694  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_1699  Mean90Days_1700  Mean90Days_1723  Mean90Days_1743  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_1770  Mean90Days_1777  Mean90Days_1780  Mean90Days_1811  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_1841  Mean90Days_1911  Mean90Days_1955  Mean90Days_1958  \
# 2703          5.266667              NaN              NaN              NaN
# 33984         0.800000              NaN              NaN              NaN
# 33929         9.300000              NaN              NaN              NaN
# 48228         1.700000              NaN              NaN              NaN
# 35408         0.900000              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720         2.300000              NaN              NaN              NaN
# 35760         1.300000              NaN              NaN              NaN
# 35783         3.100000              NaN              NaN              NaN
# 38878         0.590000              NaN              NaN              NaN
# 38873         0.420000              NaN              NaN              NaN
#
#        Mean90Days_1959  Mean90Days_1975  Mean90Days_2539  Mean90Days_2872  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_2879  Mean90Days_2904  Mean90Days_2923  Mean90Days_2925  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_3336  Mean90Days_5275  Mean90Days_5474  Mean90Days_5986  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_6249  Mean90Days_6372  Mean90Days_6598  Mean90Days_6600  \
# 2703               NaN              NaN              NaN              NaN
# 33984              NaN              NaN              NaN              NaN
# 33929              NaN              NaN              NaN              NaN
# 48228              NaN              NaN              NaN              NaN
# 35408              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 42720              NaN              NaN              NaN              NaN
# 35760              NaN              NaN              NaN              NaN
# 35783              NaN              NaN              NaN              NaN
# 38878              NaN              NaN              NaN              NaN
# 38873              NaN              NaN              NaN              NaN
#
#        Mean90Days_7074  Mean90Days_XOMP   IBD   IBD_EQR IBD_EQR_Status
# 2703               NaN              NaN  10.5  0.555556       Moderate
# 33984              NaN              NaN  20.0  1.000000           High
# 33929              NaN              NaN  20.0  1.000000           High
# 48228              NaN              NaN   NaN       NaN            NaN
# 35408              NaN              NaN  16.6  0.773333       Moderate
# ...                ...              ...   ...       ...            ...
# 42720              NaN              NaN  14.5  0.633333       Moderate
# 35760              NaN              NaN  16.3  0.753333       Moderate
# 35783              NaN              NaN  14.8  0.653333       Moderate
# 38878              NaN              NaN  20.0  1.000000           High
# 38873              NaN              NaN  20.0  1.000000           High
#
# [49231 rows x 2853 columns]

# %%
# # drop Longitude_Lambert93	Latitude_Lambert93	Watershed	CodeDepartement	HERlvl1Code	HERlvl1Name	HERlvl2Code	HERlvl2Name	Altitude
# df = df.drop(columns=['Longitude_Lambert93','Latitude_Lambert93','Watershed','CodeDepartement','HERlvl1Code','HERlvl1Name','HERlvl2Code','HERlvl2Name','Altitude', 'IBD_EQR', 'IBD_EQR_Status'])

# %%
df = df.drop(columns=['IBD_EQR', 'IBD_EQR_Status'])

# %% [markdown]
# ## No validation set

# %%
import numpy as np
import pandas as pd
from typing import Tuple, Optional
from catboost import CatBoostRegressor

def fit_catboost_and_fill(
    cleandf: pd.DataFrame,
    target: str = "IBD",
    base: Optional[dict] = None,         # e.g., {"loss_function":"RMSE","iterations":1500,"learning_rate":0.03,"depth":8}
    cat_params: Optional[dict] = None,
    use_ohe: bool = False                # False = native categoricals (recommended)
) -> Tuple[CatBoostRegressor, pd.DataFrame]:
    """
    Train on all rows with known target, then predict target for rows with NaN.
    Drops ['IBD','IBD_EQR','IBD_EQR_Status'] from features if present.
    Returns (fitted_model, scored_df) where scored_df = rows with NaN target + target_pred.
    """

    # 1) split into train/score by target presence
    df_train = cleandf[cleandf[target].notna()].copy()
    df_score = cleandf[cleandf[target].isna()].copy()

    # 2) drop leakage columns
    drop_cols = [c for c in ["IBD", "IBD_EQR", "IBD_EQR_Status"] if c in cleandf.columns]

    X = df_train.drop(columns=drop_cols + [target], errors="ignore")
    y = df_train[target].astype(float)

    # 3) detect dtypes
    num_cols = X.select_dtypes(include=[np.number]).columns.tolist()
    cat_cols = X.select_dtypes(exclude=[np.number]).columns.tolist()

    # 4) light preprocessing
    # numeric: leave NaN (CatBoost handles); categorical: fill with "(missing)"
    X_num = X[num_cols].copy()
    X_cat = X[cat_cols].copy().fillna("(missing)")

    if use_ohe:
        X_cat = pd.get_dummies(X_cat, drop_first=False)
        X_tr_proc = pd.concat([X_num.reset_index(drop=True),
                               X_cat.reset_index(drop=True)], axis=1)
        cat_features = None
    else:
        X_tr_proc = pd.concat([X_num.reset_index(drop=True),
                               X_cat.reset_index(drop=True)], axis=1)
        cat_features = list(range(len(num_cols), len(num_cols) + len(cat_cols)))

    # 5) params and fit on ALL training data (no eval_set, no early stopping)
    base_params = base
    if cat_params:
        base_params.update(cat_params)

    model = CatBoostRegressor(**base_params)

    fit_kwargs = dict(X=X_tr_proc, y=y, use_best_model=False)
    if not use_ohe:
        fit_kwargs["cat_features"] = cat_features
    model.fit(**fit_kwargs)

    # 6) score NaN-target rows
    if df_score.empty:
        scored_df = pd.DataFrame(columns=list(cleandf.columns) + [f"{target}_pred"])
        return model, scored_df

    Xs = df_score.drop(columns=drop_cols + [target], errors="ignore")
    Xs_num = Xs[num_cols].copy()
    Xs_cat = Xs[cat_cols].copy().fillna("(missing)")

    if use_ohe:
        Xs_cat = pd.get_dummies(Xs_cat, drop_first=False)
        Xs_cat = Xs_cat.reindex(columns=X_cat.columns, fill_value=0)
        Xs_proc = pd.concat([Xs_num.reset_index(drop=True),
                             Xs_cat.reset_index(drop=True)], axis=1)
    else:
        Xs_proc = pd.concat([Xs_num.reset_index(drop=True),
                             Xs_cat.reset_index(drop=True)], axis=1)

    df_score[f"{target}_pred"] = model.predict(Xs_proc)
    scored_df = df_score

    return model, scored_df

# %% [markdown]
# # Validation set

# %%
# ===================== CatBoost (Regression) + FULL DIAGNOSTICS =====================
# pip install catboost scikit-learn matplotlib
# optional: pip install scipy shap

import numpy as np
import pandas as pd
from pathlib import Path
from typing import Tuple, Dict, Any, Optional
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt
import seaborn as sns
from scripts import style
style.mpl_apply()


try:
    from scipy import stats as _scipy_stats
except Exception:
    _scipy_stats = None

def _safe_ax(title: str, xlabel: str, ylabel: str):
    fig, ax = plt.subplots(figsize=(6.5, 4.0))
    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.grid(True, alpha=0.25)
    return fig, ax

def _maybe_save(fig, outdir: Optional[Path], name: str, dpi: int = 140):
    if outdir:
        outdir.mkdir(parents=True, exist_ok=True)
        fig.savefig(outdir / f"{name}.png", bbox_inches="tight", dpi=dpi)

def _topn(series: pd.Series, k: int = 25) -> pd.Series:
    s = series.sort_values(ascending=False)
    return s.iloc[: min(k, len(s))]

def train_catboost_region_tunueado(
    cleandf: pd.DataFrame,
    target: str = "IBD",
    base: Optional[dict] = None,
    test_size: float = 0.10,
    random_state: int = 863,
    cat_params: Optional[dict] = None,
    use_ohe: bool = False,
    plots: bool = True,
    outdir: Optional[str] = None,
    perm_repeats: int = 10,
    perm_max_samples: int = 4000,
    shap_max_samples: int = 3000,
) -> Tuple["CatBoostRegressor", Dict[str, Any], pd.DataFrame, Dict[str, Any]]:
    """
    Train CatBoostRegressor with a validation split and produce exhaustive diagnostics.

    Returns:
        model: fitted CatBoostRegressor
        metrics: dict with train/valid metrics and overfitting gap
        scored_df: rows with missing target, with target_pred column if any
        artifacts: dict with evaluation results, feature importances, figures
                   keys: evals, figs, fi_split, fi_perm, preds_train, preds_valid
    """
    from catboost import CatBoostRegressor

    outdir_p = Path(outdir) if outdir else None

    # -----------------------------
    # 1) split train/score
    # -----------------------------
    df_train = cleandf[cleandf[target].notna()].copy()
    df_score = cleandf[cleandf[target].isna()].copy()

    drop_cols = [c for c in ["IBD", "IBD_EQR", "IBD_EQR_Status"] if c in cleandf.columns]

    X = df_train.drop(columns=drop_cols + [target], errors="ignore")
    y = df_train[target].astype(float)

    X_tr, X_te, y_tr, y_te = train_test_split(
        X, y, test_size=test_size, random_state=random_state
    )

    # -----------------------------
    # 2) numeric / categorical
    # -----------------------------
    num_cols = X_tr.select_dtypes(include=[np.number]).columns.tolist()
    cat_cols = X_tr.select_dtypes(exclude=[np.number]).columns.tolist()

    # -----------------------------
    # 3) light imputations
    # -----------------------------
    # numeric: leave NaN (CatBoost handles); categorical: '(missing)'
    X_tr_num = X_tr[num_cols].copy()
    X_te_num = X_te[num_cols].copy()

    X_tr_cat = X_tr[cat_cols].copy().fillna("(missing)")
    X_te_cat = X_te[cat_cols].copy().fillna("(missing)")

    if use_ohe:
        X_tr_cat = pd.get_dummies(X_tr_cat, drop_first=False)
        X_te_cat = pd.get_dummies(X_te_cat, drop_first=False)
        X_tr_cat, X_te_cat = X_tr_cat.align(X_te_cat, join="left", axis=1, fill_value=0)
        X_tr_proc = pd.concat([X_tr_num.reset_index(drop=True),
                               X_tr_cat.reset_index(drop=True)], axis=1)
        X_te_proc = pd.concat([X_te_num.reset_index(drop=True),
                               X_te_cat.reset_index(drop=True)], axis=1)
        cat_features = None
        feature_names = list(X_tr_proc.columns)
    else:
        X_tr_proc = pd.concat([X_tr_num.reset_index(drop=True),
                               X_tr_cat.reset_index(drop=True)], axis=1)
        X_te_proc = pd.concat([X_te_num.reset_index(drop=True),
                               X_te_cat.reset_index(drop=True)], axis=1)
        cat_features = list(range(len(num_cols), len(num_cols) + len(cat_cols)))
        feature_names = num_cols + cat_cols

    # -----------------------------
    # 4) parameters
    # -----------------------------
    base_defaults = dict(
        loss_function="RMSE",
        eval_metric="RMSE",
        iterations=5000,
        learning_rate=0.05,
        depth=8,
        l2_leaf_reg=3.0,
        random_seed=random_state,
        od_type="Iter",   # early stopping
        od_wait=200,
        bootstrap_type="Bayesian",
        bagging_temperature=0.2,
        verbose=200,
        allow_writing_files=False,
        grow_policy="Lossguide",
        min_data_in_leaf=16,
    )
    base_params = dict(base_defaults)
    if base:
        base_params.update(base)
    if cat_params:
        base_params.update(cat_params)

    model = CatBoostRegressor(**base_params)

    # -----------------------------
    # 5) fit with eval_set
    # -----------------------------
    fit_kwargs = dict(
        X=X_tr_proc, y=y_tr,
        eval_set=(X_te_proc, y_te),
        use_best_model=True,
    )
    if not use_ohe:
        fit_kwargs["cat_features"] = cat_features

    model.fit(**fit_kwargs)

    # -----------------------------
    # 6) metrics
    # -----------------------------
    pred_tr = model.predict(X_tr_proc)
    pred_te = model.predict(X_te_proc)

    def _rmse(y_true, y_hat):
        return float(np.sqrt(mean_squared_error(y_true, y_hat)))

    r2_tr = float(r2_score(y_tr, pred_tr))
    r2_te = float(r2_score(y_te, pred_te))
    rmse_tr = _rmse(y_tr, pred_tr)
    rmse_te = _rmse(y_te, pred_te)
    mae_tr = float(mean_absolute_error(y_tr, pred_tr))
    mae_te = float(mean_absolute_error(y_te, pred_te))

    best_iter = int(model.get_best_iteration() or model.tree_count_)
    metrics = {
        "R2_train": r2_tr,
        "R2_valid": r2_te,
        "MAE_train": mae_tr,
        "MAE_valid": mae_te,
        "RMSE_train": rmse_tr,
        "RMSE_valid": rmse_te,
        "best_iterations": best_iter,
        "gap_R2": float(r2_tr - r2_te),
        "gap_RMSE": float(rmse_te - rmse_tr),
        "used_ohe": bool(use_ohe),
        "n_train": int(len(y_tr)),
        "n_valid": int(len(y_te)),
        "n_features": int(len(feature_names)),
    }

    # -----------------------------
    # 7) score rows without target
    # -----------------------------
    if not df_score.empty:
        Xs = df_score.drop(columns=drop_cols + [target], errors="ignore")
        Xs_num = Xs[num_cols].copy()
        Xs_cat = Xs[cat_cols].copy().fillna("(missing)")
        if use_ohe:
            Xs_cat = pd.get_dummies(Xs_cat, drop_first=False)
            Xs_cat = Xs_cat.reindex(columns=X_tr_cat.columns, fill_value=0)
            Xs_proc = pd.concat([Xs_num.reset_index(drop=True),
                                 Xs_cat.reset_index(drop=True)], axis=1)
        else:
            Xs_proc = pd.concat([Xs_num.reset_index(drop=True),
                                 Xs_cat.reset_index(drop=True)], axis=1)
        df_score[target + "_pred"] = model.predict(Xs_proc)
        scored_df = df_score
    else:
        scored_df = pd.DataFrame(columns=list(cleandf.columns) + [target + "_pred"])

    # -----------------------------
    # 8) diagnostics: eval curves, residuals, importances, SHAP (optional)
    # -----------------------------
    artifacts: Dict[str, Any] = {}
    figs: Dict[str, Any] = {}

    # 8.1 learning curves
    evals = model.get_evals_result()
    artifacts["evals"] = evals
    if plots and evals and "learn" in evals and "validation" in evals:
        for metric_name in evals["learn"].keys():
            learn_vals = evals["learn"][metric_name]
            valid_vals = evals["validation"][metric_name]
            fig, ax = _safe_ax(f"Learning curve ({metric_name})",
                               "Iteration", metric_name)
            ax.plot(range(1, len(learn_vals) + 1), learn_vals, label="train")
            ax.plot(range(1, len(valid_vals) + 1), valid_vals, label="valid")
            ax.axvline(best_iter, ls="--", alpha=0.5, label="best_iter")
            ax.legend()
            _maybe_save(fig, outdir_p, f"curve_{metric_name}")
            figs[f"curve_{metric_name}"] = fig

    # 8.2 predicted vs actual (train/valid)
    if plots:
        # train
        fig, ax = _safe_ax("Predicted vs Actual (train)", "Actual", "Predicted")
        ax.scatter(y_tr, pred_tr, s=8, alpha=0.35)
        lo = np.nanmin([y_tr.min(), pred_tr.min()])
        hi = np.nanmax([y_tr.max(), pred_tr.max()])
        ax.plot([lo, hi], [lo, hi], ls="--")
        _maybe_save(fig, outdir_p, "pva_train")
        figs["pva_train"] = fig

        # valid
        fig, ax = _safe_ax("Predicted vs Actual (valid)", "Actual", "Predicted")
        ax.scatter(y_te, pred_te, s=10, alpha=0.45)
        lo = np.nanmin([y_te.min(), pred_te.min()])
        hi = np.nanmax([y_te.max(), pred_te.max()])
        ax.plot([lo, hi], [lo, hi], ls="--")
        _maybe_save(fig, outdir_p, "pva_valid")
        figs["pva_valid"] = fig

    # 8.3 residual plots
    res_tr = y_tr - pred_tr
    res_te = y_te - pred_te
    artifacts["preds_train"] = pd.DataFrame({"y": y_tr, "yhat": pred_tr, "resid": res_tr}).reset_index(drop=True)
    artifacts["preds_valid"] = pd.DataFrame({"y": y_te, "yhat": pred_te, "resid": res_te}).reset_index(drop=True)

    if plots:
        # histograms
        fig, ax = _safe_ax("Residuals histogram (train/valid)", "Residual", "Count")
        ax.hist(res_tr, bins=50, alpha=0.5, label="train")
        ax.hist(res_te, bins=50, alpha=0.5, label="valid")
        ax.legend()
        _maybe_save(fig, outdir_p, "residual_hist")
        figs["residual_hist"] = fig

        # residual vs fitted (valid)
        fig, ax = _safe_ax("Residuals vs Fitted (valid)", "Fitted", "Residual")
        ax.scatter(pred_te, res_te, s=10, alpha=0.45)
        ax.axhline(0.0, ls="--")
        _maybe_save(fig, outdir_p, "residual_vs_fitted_valid")
        figs["residual_vs_fitted_valid"] = fig

        # QQ plot (valid)
        if _scipy_stats is not None:
            fig = plt.figure(figsize=(5.0, 5.0))
            _scipy_stats.probplot(res_te, dist="norm", plot=plt)
            plt.title("QQ-plot of residuals (valid)")
            _maybe_save(fig, outdir_p, "qqplot_valid")
            figs["qqplot_valid"] = fig

    # 8.4 feature importance (split-based from CatBoost)
    try:
        fi_pretty = model.get_feature_importance(type="FeatureImportance",
                                                 prettified=True)
        fi_split = pd.DataFrame(fi_pretty)
        # ensure consistent column names
        if "Feature Id" in fi_split.columns and "Importance" in fi_split.columns:
            fi_split = fi_split.rename(columns={"Feature Id": "feature",
                                                "Importance": "importance"})
        elif set(["Feature Id", "Importances"]).issubset(fi_split.columns):
            fi_split = fi_split.rename(columns={"Feature Id": "feature",
                                                "Importances": "importance"})
        artifacts["fi_split"] = fi_split
        if plots and not fi_split.empty:
            top = _topn(fi_split.set_index("feature")["importance"], 30)
            fig, ax = _safe_ax("Feature importance (split-based, top 30)",
                               "Importance", "Feature")
            ax.barh(top.index[::-1], top.values[::-1])
            _maybe_save(fig, outdir_p, "fi_split_top30")
            figs["fi_split_top30"] = fig
    except Exception:
        artifacts["fi_split"] = pd.DataFrame(columns=["feature", "importance"])

    # 8.6 SHAP summary (optional)
    if plots:
        try:
            import shap
            # small sample for speed; use processed matrices to match model expectation
            if len(X_te_proc) > shap_max_samples:
                rng = np.random.default_rng(random_state)
                idx = rng.choice(len(X_te_proc), size=shap_max_samples, replace=False)
                X_shap = X_te_proc.iloc[idx]
            else:
                X_shap = X_te_proc

            explainer = shap.TreeExplainer(model)
            shap_values = explainer.shap_values(X_shap)
            # summary plot
            fig = plt.figure(figsize=(7.0, 5.0))
            shap.summary_plot(shap_values, X_shap, show=False, max_display=25)
            plt.title("SHAP summary (valid sample)")
            _maybe_save(fig, outdir_p, "shap_summary")
            figs["shap_summary"] = fig
            artifacts["shap_sample_size"] = int(len(X_shap))
        except Exception:
            pass

    artifacts["figs"] = figs

    return model, metrics, scored_df, artifacts

# %% [markdown]
# # Tobit Style Correction

# %%
# ===================== CatBoost (Regression) + Censoring + Full Diagnostics =====================
import numpy as np, pandas as pd
from pathlib import Path
from typing import Tuple, Dict, Any, Optional
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
from scripts import style
style.mpl_apply()

try:
    from scipy import stats as _scipy_stats
except Exception:
    _scipy_stats = None

def _phi(z): return np.exp(-0.5*z*z)/np.sqrt(2*np.pi)
def _Phi(z):
    import math
    return 0.5*(1.0 + np.vectorize(math.erf)(z/np.sqrt(2.0)))

def _safe_ax(title, xlabel, ylabel):
    fig, ax = plt.subplots(figsize=(6.5,4.0))
    ax.set_title(title); ax.set_xlabel(xlabel); ax.set_ylabel(ylabel); ax.grid(True, alpha=0.25)
    return fig, ax

def _maybe_save(fig, outdir: Optional[Path], name: str, dpi: int = 140):
    if outdir: outdir.mkdir(parents=True, exist_ok=True); fig.savefig(outdir/f"{name}.png", bbox_inches="tight", dpi=dpi)

def _topn(series: pd.Series, k: int = 25) -> pd.Series:
    s = series.sort_values(ascending=False); return s.iloc[:min(k, len(s))]

def _build_mats(dfX: pd.DataFrame, drop_cols: list, target: str,
                use_ohe: bool, num_cols_ref=None, cat_cols_ref=None,
                ohe_cols_ref=None):
    """Return X_proc, feature_names, cat_features, metadata. Guarantees [num | cat] order."""
    X = dfX.drop(columns=drop_cols+[target], errors="ignore")

    # detect cols or reuse ref
    if num_cols_ref is None or cat_cols_ref is None:
        num_cols = X.select_dtypes(include=[np.number]).columns.tolist()
        cat_cols = X.columns.difference(num_cols).tolist()
    else:
        num_cols, cat_cols = list(num_cols_ref), list(cat_cols_ref)

    # keep order: all numerics first, then categoricals
    X_num = X[num_cols].copy()
    X_cat = X[cat_cols].copy().fillna("(missing)")

    if use_ohe:
        X_cat = pd.get_dummies(X_cat, drop_first=False)
        if ohe_cols_ref is not None:
            X_cat = X_cat.reindex(columns=ohe_cols_ref, fill_value=0)
        X_proc = pd.concat([X_num.reset_index(drop=True),
                            X_cat.reset_index(drop=True)], axis=1)
        feature_names = list(X_proc.columns)
        cat_features = None
        meta = dict(num_cols=num_cols, cat_cols=cat_cols, ohe_cols=list(X_cat.columns))
    else:
        X_proc = pd.concat([X_num.reset_index(drop=True),
                            X_cat.reset_index(drop=True)], axis=1)
        feature_names = num_cols + cat_cols
        cat_features = list(range(len(num_cols), len(num_cols)+len(cat_cols)))
        meta = dict(num_cols=num_cols, cat_cols=cat_cols, ohe_cols=None)

    return X_proc, feature_names, cat_features, meta

def train_catboost_region_tunueado_censored(
    cleandf: pd.DataFrame,
    target: str = "IBD",
    base: Optional[dict] = None,
    test_size: float = 0.10,
    random_state: int = 863,
    cat_params: Optional[dict] = None,
    use_ohe: bool = False,
    plots: bool = True,
    outdir: Optional[str] = None,
    shap_max_samples: int = 3000,
    # censoring
    censor_value: float = 20.0,
    sigma_method: str = "mad",
    eps: float = 1e-12,
) -> Tuple["CatBoostRegressor", Dict[str, Any], pd.DataFrame, Dict[str, Any]]:
    from catboost import CatBoostRegressor

    outdir_p = Path(outdir) if outdir else None

    # 1) robust target coercion
    df_y = cleandf[cleandf[target].notna()].copy()
    df_score = cleandf[cleandf[target].isna()].copy()
    y_num = pd.to_numeric(df_y[target], errors="coerce")
    non_numeric_dropped = int(y_num.isna().sum())
    if non_numeric_dropped:
        df_y = df_y.loc[y_num.notna()].copy()
        y_num = y_num.loc[y_num.notna()]
    df_y[target] = y_num.astype(float)

    mask_unc = df_y[target] < float(censor_value)
    df_unc, df_cens = df_y.loc[mask_unc].copy(), df_y.loc[~mask_unc].copy()

    drop_cols = [c for c in ["IBD", "IBD_EQR", "IBD_EQR_Status"] if c in cleandf.columns]

    # 2) matrices for UNCENSORED
    X_unc_proc, feat_names, cat_features, meta = _build_mats(
        df_unc, drop_cols, target, use_ohe,
    )

    # 3) split and fit
    from sklearn.model_selection import train_test_split
    y_unc = df_unc[target].astype(float)
    X_tr, X_te, y_tr, y_te = train_test_split(X_unc_proc, y_unc, test_size=test_size, random_state=random_state)

    base_defaults = dict(
        loss_function="RMSE", eval_metric="RMSE",
        iterations=5000, learning_rate=0.05, depth=8, l2_leaf_reg=3.0,
        random_seed=random_state, od_type="Iter", od_wait=200,
        bootstrap_type="Bayesian", bagging_temperature=0.2,
        verbose=200, allow_writing_files=False,
        grow_policy="Lossguide", min_data_in_leaf=16,
    )
    params = {**base_defaults, **(base or {}), **(cat_params or {})}
    model = CatBoostRegressor(**params)
    fit_kwargs = dict(X=X_tr, y=y_tr, eval_set=(X_te, y_te), use_best_model=True)
    if not use_ohe: fit_kwargs["cat_features"] = cat_features
    model.fit(**fit_kwargs)

    # 4) uncensored metrics
    def _rmse(y_true, y_hat): return float(np.sqrt(mean_squared_error(y_true, y_hat)))
    pred_tr, pred_te = model.predict(X_tr), model.predict(X_te)
    r2_tr, r2_te = float(r2_score(y_tr, pred_tr)), float(r2_score(y_te, pred_te))
    rmse_tr, rmse_te = _rmse(y_tr, pred_tr), _rmse(y_te, pred_te)
    mae_tr, mae_te = float(mean_absolute_error(y_tr, pred_tr)), float(mean_absolute_error(y_te, pred_te))
    best_iter = int(model.get_best_iteration() or model.tree_count_)

    # 5) sigma for correction
    resid_tr = y_tr - pred_tr
    if sigma_method.lower() == "mad":
        med = float(np.median(resid_tr)); sigma = 1.4826 * float(np.median(np.abs(resid_tr - med)))
    else:
        sigma = float(np.std(resid_tr, ddof=1))
    sigma = max(sigma, 1e-3)

    def _tobit_correct(yhat: np.ndarray, c: float, s: float) -> np.ndarray:
        z = (c - yhat) / s
        tail = _phi(z) / np.maximum(1.0 - _Phi(z), eps)
        return np.where(yhat < c, yhat, c + s * tail)

    pred_te_corr = _tobit_correct(pred_te, censor_value, sigma)

    # 6) score rows without target (align to training)
    def _proc_like_train(dfX: pd.DataFrame) -> pd.DataFrame:
        return _build_mats(
            dfX, drop_cols, target, use_ohe,
            num_cols_ref=meta["num_cols"], cat_cols_ref=meta["cat_cols"],
            ohe_cols_ref=meta["ohe_cols"],
        )[0]

    if not df_score.empty:
        Xs_proc = _proc_like_train(df_score)
        yhat_raw = model.predict(Xs_proc)
        yhat_corr = _tobit_correct(yhat_raw, censor_value, sigma)
        df_score[target+"_pred_raw"]  = yhat_raw
        df_score[target+"_pred_corr"] = yhat_corr
        scored_df = df_score
    else:
        scored_df = pd.DataFrame(columns=list(cleandf.columns)+[target+"_pred_raw", target+"_pred_corr"])

    # 7) diagnostics
    artifacts, figs = {}, {}
    evals = model.get_evals_result(); artifacts["evals"] = evals
    if plots and evals and "learn" in evals and "validation" in evals:
        for metric_name in evals["learn"].keys():
            fig, ax = _safe_ax(f"Learning curve ({metric_name})","Iteration",metric_name)
            ax.plot(range(1,len(evals["learn"][metric_name])+1), evals["learn"][metric_name], label="train")
            ax.plot(range(1,len(evals["validation"][metric_name])+1), evals["validation"][metric_name], label="valid")
            ax.axvline(best_iter, ls="--", alpha=0.5, label="best_iter"); ax.legend()
            _maybe_save(fig, outdir_p, f"curve_{metric_name}"); figs[f"curve_{metric_name}"]=fig

    if plots:
        fig, ax = _safe_ax("PVA (train, uncensored)","Actual","Predicted")
        ax.scatter(y_tr, pred_tr, s=8, alpha=0.35)
        lo = float(np.nanmin([y_tr.min(), pred_tr.min()])); hi = float(np.nanmax([y_tr.max(), pred_tr.max(), censor_value]))
        ax.plot([lo,hi],[lo,hi], ls="--"); ax.axvline(censor_value, color="r", alpha=0.4); ax.axhline(censor_value, color="r", alpha=0.4)
        _maybe_save(fig, outdir_p, "pva_train_unc"); figs["pva_train_unc"]=fig

        fig, ax = _safe_ax("PVA (valid, uncensored) raw vs corr","Actual","Predicted")
        ax.scatter(y_te, pred_te, s=10, alpha=0.45, label="raw")
        ax.scatter(y_te, pred_te_corr, s=10, alpha=0.45, label="corr", marker="x")
        ax.plot([lo,hi],[lo,hi], ls="--"); ax.axvline(censor_value, color="r", alpha=0.4); ax.axhline(censor_value, color="r", alpha=0.4)
        ax.legend(); _maybe_save(fig, outdir_p, "pva_valid_unc"); figs["pva_valid_unc"]=fig

        res_te = y_te - pred_te
        fig, ax = _safe_ax("Residuals hist (uncensored)","Residual","Count")
        ax.hist(y_tr - pred_tr, bins=50, alpha=0.5, label="train"); ax.hist(res_te, bins=50, alpha=0.5, label="valid")
        ax.legend(); _maybe_save(fig, outdir_p, "residual_hist_unc"); figs["residual_hist_unc"]=fig

        fig, ax = _safe_ax("Residuals vs Fitted (valid, uncensored)","Fitted","Residual")
        ax.scatter(pred_te, res_te, s=10, alpha=0.45); ax.axhline(0.0, ls="--")
        _maybe_save(fig, outdir_p, "residual_vs_fitted_valid_unc"); figs["residual_vs_fitted_valid_unc"]=fig

        if _scipy_stats is not None:
            fig = plt.figure(figsize=(5,5)); _scipy_stats.probplot(res_te, dist="norm", plot=plt)
            plt.title("QQ-plot (valid, uncensored)"); _maybe_save(fig, outdir_p, "qqplot_valid_unc"); figs["qqplot_valid_unc"]=fig

        # target censoring diagnostic
        fig, ax = _safe_ax("Target distribution with censoring", target, "Count")
        ax.hist(df_y[target], bins=80, alpha=0.7); ax.axvline(censor_value, color="r", lw=2, label=f"censor={censor_value}")
        ax.legend(); _maybe_save(fig, outdir_p, "target_censor_hist"); figs["target_censor_hist"]=fig

    # feature importance
    try:
        fi_pretty = model.get_feature_importance(type="FeatureImportance", prettified=True)
        fi = pd.DataFrame(fi_pretty)
        if "Feature Id" in fi.columns and "Importance" in fi.columns:
            fi = fi.rename(columns={"Feature Id":"feature","Importance":"importance"})
        elif set(["Feature Id","Importances"]).issubset(fi.columns):
            fi = fi.rename(columns={"Feature Id":"feature","Importances":"importance"})
        if plots and not fi.empty:
            top = _topn(fi.set_index("feature")["importance"], 30)
            fig, ax = _safe_ax("Feature importance (top 30)","Importance","Feature")
            ax.barh(top.index[::-1], top.values[::-1]); _maybe_save(fig, outdir_p, "fi_split_top30"); figs["fi_split_top30"]=fig
    except Exception:
        fi = pd.DataFrame(columns=["feature","importance"])

    artifacts = {
        "figs": figs,
        "fi_split": fi,
        "censor_stats": {
            "censor_value": float(censor_value),
            "n_uncensored_used": int(len(df_unc)),
            "n_censored_observed": int(len(df_cens)),
            "n_non_numeric_dropped": int(non_numeric_dropped),
            "sigma_resid": float(sigma),
        }
    }

    metrics = {
        "R2_train_unc": r2_tr, "R2_valid_unc": r2_te,
        "MAE_train_unc": mae_tr, "MAE_valid_unc": mae_te,
        "RMSE_train_unc": rmse_tr, "RMSE_valid_unc": rmse_te,
        "best_iterations": best_iter,
        "gap_R2_unc": float(r2_tr - r2_te),
        "gap_RMSE_unc": float(rmse_te - rmse_tr),
        "used_ohe": bool(use_ohe),
        "n_train_unc": int(len(y_tr)), "n_valid_unc": int(len(y_te)),
        "n_features": int(len(feat_names)),
    }

    return model, metrics, scored_df, artifacts

# %% [markdown]
# # Training

# %%
from catboost.utils import get_gpu_device_count
print("GPUs visible to CatBoost:", get_gpu_device_count())
# Out:
# GPUs visible to CatBoost: 1

# %%
base_opt = dict(
    task_type="GPU",
    devices="0",

    # Objetivo
    loss_function="RMSE",
    eval_metric="RMSE",

    # Iteraciones largas con parada temprana robusta
    iterations=10000,
    learning_rate=0.01,          # más bajo, más estable
    od_type="Iter",
    od_wait=300,                 # mayor paciencia para curvas ruidosas
    random_seed=863,

    # Complejidad y estructura
    depth=16,                     # menos overfitting que 10
    grow_policy="Lossguide",     # útil para muchas columnas
    min_data_in_leaf=64,         # hojas más estables

    # Regularización
    l2_leaf_reg=1,             # controla peso L2 en hojas
    random_strength=1,         # aleatoriedad en splits
    bagging_temperature=1,     # menor => más determinista, mejor generalización
    # subsample=0.8,               # añade bagging (en GPU lo soporta)
    # colsample_bylevel=0.8,       # reducción dimensional regularizadora

    # Binning y ruido
    max_bin=254,                 # binning fino mejora precisión en datos densos
    
    # Logging
    verbose=200
)

# %%
import os
from pathlib import Path
name ="Truncated"
outdir=f"visualizations/Catboost_TPEPM{name}"
# CREATE OUTPUT DIRECTORY IF IT DOESN'T EXIST
Path(outdir).mkdir(parents=True, exist_ok=True)

# %%
model, metrics, scored_df, artifacts = train_catboost_region_tunueado_censored(
    cleandf=df,
    target="IBD",
    censor_value=20.0,
    base=base_opt,
    outdir="visualizations/Catboost_TPEPM{name}",
)
# Out:
# 0:	learn: 2.4329183	test: 2.4464144	best: 2.4464144 (0)	total: 41.3ms	remaining: 6m 53s
# 200:	learn: 1.1110645	test: 1.1779914	best: 1.1779914 (200)	total: 6.98s	remaining: 5m 40s
# 400:	learn: 0.7957724	test: 0.8874701	best: 0.8874701 (400)	total: 13.8s	remaining: 5m 31s
# 600:	learn: 0.6657473	test: 0.7664872	best: 0.7664872 (600)	total: 20.1s	remaining: 5m 15s
# 800:	learn: 0.5912642	test: 0.6992198	best: 0.6992198 (800)	total: 27s	remaining: 5m 10s
# 1000:	learn: 0.5424353	test: 0.6563861	best: 0.6563861 (1000)	total: 33.7s	remaining: 5m 3s
# 1200:	learn: 0.5066380	test: 0.6273568	best: 0.6273568 (1200)	total: 39.7s	remaining: 4m 50s
# 1400:	learn: 0.4792288	test: 0.6055589	best: 0.6055589 (1400)	total: 45.8s	remaining: 4m 41s
# 1600:	learn: 0.4567122	test: 0.5886958	best: 0.5886958 (1600)	total: 51.6s	remaining: 4m 30s
# 1800:	learn: 0.4379620	test: 0.5751472	best: 0.5751472 (1800)	total: 57.5s	remaining: 4m 21s
# 2000:	learn: 0.4212418	test: 0.5637089	best: 0.5637089 (2000)	total: 1m 3s	remaining: 4m 12s
# 2200:	learn: 0.4070547	test: 0.5540066	best: 0.5540066 (2200)	total: 1m 8s	remaining: 4m 3s
# 2400:	learn: 0.3941943	test: 0.5456925	best: 0.5456925 (2400)	total: 1m 14s	remaining: 3m 55s
# 2600:	learn: 0.3823242	test: 0.5384403	best: 0.5384403 (2600)	total: 1m 19s	remaining: 3m 47s
# 2800:	learn: 0.3715724	test: 0.5320279	best: 0.5320279 (2800)	total: 1m 25s	remaining: 3m 40s
# 3000:	learn: 0.3619952	test: 0.5262781	best: 0.5262781 (3000)	total: 1m 30s	remaining: 3m 31s
# 3200:	learn: 0.3527441	test: 0.5209684	best: 0.5209684 (3200)	total: 1m 35s	remaining: 3m 22s
# 3400:	learn: 0.3444742	test: 0.5164271	best: 0.5164271 (3400)	total: 1m 40s	remaining: 3m 14s
# 3600:	learn: 0.3364059	test: 0.5121288	best: 0.5121288 (3600)	total: 1m 44s	remaining: 3m 6s
# 3800:	learn: 0.3294514	test: 0.5082421	best: 0.5082421 (3800)	total: 1m 49s	remaining: 2m 58s
# 4000:	learn: 0.3224367	test: 0.5045568	best: 0.5045568 (4000)	total: 1m 54s	remaining: 2m 51s
# 4200:	learn: 0.3163039	test: 0.5013877	best: 0.5013877 (4200)	total: 1m 59s	remaining: 2m 44s
# 4400:	learn: 0.3103598	test: 0.4983842	best: 0.4983842 (4400)	total: 2m 3s	remaining: 2m 37s
# 4600:	learn: 0.3046549	test: 0.4958685	best: 0.4958657 (4598)	total: 2m 8s	remaining: 2m 30s
# 4800:	learn: 0.2993284	test: 0.4934200	best: 0.4934200 (4800)	total: 2m 13s	remaining: 2m 24s
# 5000:	learn: 0.2940342	test: 0.4910950	best: 0.4910950 (5000)	total: 2m 17s	remaining: 2m 17s
# 5200:	learn: 0.2888794	test: 0.4888938	best: 0.4888938 (5200)	total: 2m 22s	remaining: 2m 11s
# 5400:	learn: 0.2841313	test: 0.4867592	best: 0.4867592 (5400)	total: 2m 27s	remaining: 2m 5s
# 5600:	learn: 0.2796127	test: 0.4848762	best: 0.4848762 (5600)	total: 2m 32s	remaining: 1m 59s
# 5800:	learn: 0.2753204	test: 0.4830263	best: 0.4830263 (5800)	total: 2m 36s	remaining: 1m 53s
# 6000:	learn: 0.2710597	test: 0.4812478	best: 0.4812478 (6000)	total: 2m 41s	remaining: 1m 47s
# 6200:	learn: 0.2671010	test: 0.4796891	best: 0.4796887 (6199)	total: 2m 46s	remaining: 1m 41s
# 6400:	learn: 0.2631492	test: 0.4782397	best: 0.4782397 (6400)	total: 2m 50s	remaining: 1m 35s
# 6600:	learn: 0.2593636	test: 0.4768162	best: 0.4768162 (6600)	total: 2m 55s	remaining: 1m 30s
# 6800:	learn: 0.2556956	test: 0.4754839	best: 0.4754839 (6800)	total: 3m	remaining: 1m 24s
# 7000:	learn: 0.2520957	test: 0.4745299	best: 0.4745195 (6999)	total: 3m 5s	remaining: 1m 19s
# 7200:	learn: 0.2486297	test: 0.4734462	best: 0.4734462 (7200)	total: 3m 9s	remaining: 1m 13s
# 7400:	learn: 0.2453782	test: 0.4723310	best: 0.4723310 (7400)	total: 3m 14s	remaining: 1m 8s
# 7600:	learn: 0.2420540	test: 0.4713449	best: 0.4713449 (7600)	total: 3m 18s	remaining: 1m 2s
# 7800:	learn: 0.2389478	test: 0.4703751	best: 0.4703751 (7800)	total: 3m 23s	remaining: 57.4s
# 8000:	learn: 0.2358817	test: 0.4695206	best: 0.4695169 (7999)	total: 3m 28s	remaining: 52s
# 8200:	learn: 0.2329731	test: 0.4686855	best: 0.4686855 (8200)	total: 3m 33s	remaining: 46.8s
# 8400:	learn: 0.2301289	test: 0.4678605	best: 0.4678605 (8400)	total: 3m 37s	remaining: 41.5s
# 8600:	learn: 0.2273781	test: 0.4670719	best: 0.4670718 (8599)	total: 3m 42s	remaining: 36.2s
# 8800:	learn: 0.2247631	test: 0.4662901	best: 0.4662901 (8800)	total: 3m 47s	remaining: 31s
# 9000:	learn: 0.2222232	test: 0.4656349	best: 0.4656254 (8997)	total: 3m 52s	remaining: 25.7s
# 9200:	learn: 0.2196109	test: 0.4649054	best: 0.4649054 (9200)	total: 3m 57s	remaining: 20.6s
# 9400:	learn: 0.2171745	test: 0.4643451	best: 0.4643451 (9400)	total: 4m 2s	remaining: 15.5s
# 9600:	learn: 0.2146947	test: 0.4637494	best: 0.4637494 (9600)	total: 4m 8s	remaining: 10.3s
# 9800:	learn: 0.2122652	test: 0.4631823	best: 0.4631788 (9793)	total: 4m 13s	remaining: 5.15s
# 9999:	learn: 0.2098359	test: 0.4626775	best: 0.4626755 (9998)	total: 4m 20s	remaining: 0us
# bestTest = 0.4626754705
# bestIteration = 9998
# Shrink model to first 9999 iterations.

# %%
print(artifacts)
# Out:
# {'figs': {'curve_RMSE': <Figure size 650x400 with 1 Axes>, 'pva_train_unc': <Figure size 650x400 with 1 Axes>, 'pva_valid_unc': <Figure size 650x400 with 1 Axes>, 'residual_hist_unc': <Figure size 650x400 with 1 Axes>, 'residual_vs_fitted_valid_unc': <Figure size 650x400 with 1 Axes>, 'qqplot_valid_unc': <Figure size 500x500 with 1 Axes>, 'target_censor_hist': <Figure size 650x400 with 1 Axes>, 'fi_split_top30': <Figure size 650x400 with 1 Axes>}, 'fi_split':                             feature  importance
# 0     CodeSite_SamplingOperations_x   17.243275
# 1                           Achmi02   10.625552
# 2                           Navsa03   10.253533
# 3                       Mean1Y_1350    9.008987
# 4                           Navpe05    4.232380
# ...                             ...         ...
# 2845                Mean90Days_1648    0.000000
# 2846                Mean90Days_1811    0.000000
# 2847                Mean90Days_2923    0.000000
# 2848                Mean90Days_6249    0.000000
# 2849        SamplingOperations_code    0.000000
#
# [2850 rows x 2 columns], 'censor_stats': {'censor_value': 20.0, 'n_uncensored_used': 39160, 'n_censored_observed': 4408, 'n_non_numeric_dropped': 0, 'sigma_resid': 0.17630623870801934}}

# %%
print(metrics)
# Figures available in art["figs"], saved under ./cb_diagnostics/*.png if outdir provided
# Split-based importance: art["fi_split"]; Permutation importance: art["fi_perm"]
# Out:
# {'R2_train_unc': 0.9929396756557376, 'R2_valid_unc': 0.9646498126185158, 'MAE_train_unc': 0.1526490778809284, 'MAE_valid_unc': 0.27714184362984323, 'RMSE_train_unc': 0.20572056984023218, 'RMSE_valid_unc': 0.4626761180875021, 'best_iterations': 9998, 'gap_R2_unc': 0.028289863037221807, 'gap_RMSE_unc': 0.2569555482472699, 'used_ohe': False, 'n_train_unc': 35244, 'n_valid_unc': 3916, 'n_features': 2850}

# %%
scored_df
# Out:
#       SamplingOperations_code CodeSite_SamplingOperations_x  \
# 48228      S05235850_20070709                     S05235850
# 47256      S05113000_20070723                     S05113000
# 47024      S05082000_20070724                     S05082000
# 47237      S05111500_20070724                     S05111500
# 47042      S05086000_20070725                     S05086000
# ...                       ...                           ...
# 48719      S06173650_20230720                     S06173650
# 48450      S06076420_20230726                     S06076420
# 49198      S06830139_20230818                     S06830139
# 48775      S06178000_20230822                     S06178000
# 49200      S06830142_20230830                     S06830142
#
#        Date_SamplingOperation  TotalAbundance_SamplingOperation  Achaa01  \
# 48228                20070709                               400      NaN
# 47256                20070723                               433      NaN
# 47024                20070724                               400      NaN
# 47237                20070724                               414      NaN
# 47042                20070725                               424      NaN
# ...                       ...                               ...      ...
# 48719                20230720                               416      NaN
# 48450                20230726                               399      NaN
# 49198                20230818                               394      NaN
# 48775                20230822                               411      NaN
# 49200                20230830                               404      NaN
#
#        Achac01  Achaf01  Achaf02  Achal01  Acham01  Achan01  Achat01  \
# 48228      NaN      2.5      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#          Achat02  Achat03  Achba01  Achbi01  Achbi02  Achbr01  Achca01  \
# 48228  42.500000      NaN      NaN      NaN      NaN      NaN      NaN
# 47256        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237   2.415459      NaN      NaN      NaN      NaN      NaN      NaN
# 47042        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...          ...      ...      ...      ...      ...      ...      ...
# 48719        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200        NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achca02  Achca03  Achca04  Achch01  Achcl01  Achco01  Achco02  Achco03  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achco04  Achcr01  Achcy01  Achda01  Achda02  Achde01  Achde02  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN     12.5      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#           Achde03  Achdi01  Achdi02  Achdr01  Achel01  Achen01    Acheu01  \
# 48228         NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 47256         NaN      NaN      NaN      NaN      NaN      NaN  36.951501
# 47024         NaN      NaN      NaN      NaN      NaN     10.0        NaN
# 47237         NaN      NaN      NaN      NaN      NaN      NaN  36.231884
# 47042         NaN      NaN      NaN      NaN      NaN      NaN        NaN
# ...           ...      ...      ...      ...      ...      ...        ...
# 48719         NaN      NaN      NaN      NaN      NaN      NaN   2.403846
# 48450         NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 49198         NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 48775  143.552311      NaN      NaN      NaN      NaN      NaN        NaN
# 49200         NaN      NaN      NaN      NaN      NaN      NaN        NaN
#
#        Achex01  Achex02  Achex03  Achfl01  Achfr01  Achfu01  Achge01  Achgr01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN  7.50000      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN  4.86618      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achgr02  Achgr03  Achha01  Achhe01  Achhi01  Achho01  Achho02  Achho03  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achhu01  Achim01  Achim02  Achim03  Achin01  Achin02  Achja01  Achja02  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achjo01  Achko01  Achkr01  Achkr02  Achkr03  Achkr04  Achku01  Achla01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN     12.5      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#          Achla02  Achla03  Achla04  Achla05  Achla06  Achle01  Achle02  \
# 48228        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024  17.500000      NaN      NaN      NaN      NaN      NaN      NaN
# 47237        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...          ...      ...      ...      ...      ...      ...      ...
# 48719        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198   2.538071      NaN      NaN      NaN      NaN      NaN      NaN
# 48775        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200        NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achli01  Achli02     Achli03  Achli04  Achlo01  Achlu01  Achlu02  \
# 48228      NaN      NaN  215.000000      NaN      NaN      NaN      NaN
# 47256      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# ...        ...      ...         ...      ...      ...      ...      ...
# 48719      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN   27.227723      NaN      NaN      NaN      NaN
#
#        Achma01  Achmi01     Achmi02     Achmi03  Achmo01  Achmo02  Achna01  \
# 48228      NaN      NaN  237.500000         NaN      NaN      NaN      NaN
# 47256      NaN      NaN    2.309469         NaN      NaN      NaN      NaN
# 47024      NaN      NaN    2.500000         NaN      NaN      NaN      NaN
# 47237      NaN      NaN         NaN         NaN      NaN      NaN      NaN
# 47042      NaN      NaN   16.509434         NaN      NaN      NaN      NaN
# ...        ...      ...         ...         ...      ...      ...      ...
# 48719      NaN      NaN   14.423077         NaN      NaN      NaN      NaN
# 48450      NaN      NaN  228.070175         NaN      NaN      NaN      NaN
# 49198      NaN      NaN  119.289340  104.060914      NaN      NaN      NaN
# 48775      NaN      NaN   14.598540         NaN      NaN      NaN      NaN
# 49200      NaN      NaN  245.049505         NaN      NaN      NaN      NaN
#
#        Achna02  Achne01  Achni01  Achno01  Achob01  Achpa01  Achpe01  Achpe02  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achpf01  Achpl01  Achpo01  Achpr01  Achpr02  Achps01  Achps02  Achps03  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achps04  Achpu01     Achpy01  Achre01  Achri01  Achro01  Achro02  \
# 48228      NaN      NaN   40.000000      NaN      NaN      NaN      NaN
# 47256      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN    2.415459      NaN      NaN      NaN      NaN
# 47042      NaN      NaN    2.358491      NaN      NaN      NaN      NaN
# ...        ...      ...         ...      ...      ...      ...      ...
# 48719      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN   40.100251      NaN      NaN      NaN      NaN
# 49198      NaN      NaN   91.370558      NaN      NaN      NaN      NaN
# 48775      NaN      NaN         NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN  606.435644      NaN      NaN      NaN      NaN
#
#        Achro03  Achro04  Achru01  Achru02  Achsa01  Achsc01  Achse01  Achse02  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achsi01  Achst01  Achst02    Achst03  Achst04  Achsu01  Achsu02  \
# 48228      NaN      NaN      NaN        NaN      NaN     10.0      NaN
# 47256      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# ...        ...      ...      ...        ...      ...      ...      ...
# 48719      NaN      NaN      NaN  12.019231      NaN      NaN      NaN
# 48450      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN        NaN      NaN      NaN      NaN
#
#          Achsu03  Achsu04  Achsu05  Achsu06  Achsu07  Achte01  Achth01  \
# 48228        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042  11.792453      NaN      NaN      NaN      NaN      NaN      NaN
# ...          ...      ...      ...      ...      ...      ...      ...
# 48719        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775        NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200        NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Achtr01  Achtr02  Achtr03  Achtu01  Achzh01  Achzi01  Actde01  Actno01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Actro01  Actse01  Actsp01  Actsu01  Actvu01  Adlaq01  Adlba01  Adlbr01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Adlbr02   Adlmi01  Adlmu01  Adlmu02  Adlpa01  Adlsu01  Afrre01  \
# 48228      NaN       NaN      NaN      NaN      NaN      5.0      NaN
# 47256      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN  2.358491      NaN      NaN      NaN      NaN      NaN
# ...        ...       ...      ...      ...      ...      ...      ...
# 48719      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN       NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN  2.475248      NaN      NaN      NaN      NaN      NaN
#
#        Ampae01  Ampaf01  Ampal01  Ampat01  Ampbi01  Ampbu01  Ampco01  Ampcu01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Ampde01  Ampdi01  Ampdi02  Ampdu01  Ampei01  Ampex01  Ampfo01  Ampfo02  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Amphe01  Amphi01  Ampin01    Ampin02  Ampli01  Ampma01  Ampme01  \
# 48228      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# ...        ...      ...      ...        ...      ...      ...      ...
# 48719      NaN      NaN      NaN   9.615385      NaN      NaN      NaN
# 48450      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN  12.690355      NaN      NaN      NaN
# 48775      NaN      NaN      NaN   4.866180      NaN      NaN      NaN
# 49200      NaN      NaN      NaN        NaN      NaN      NaN      NaN
#
#        Ampmi01  Ampmi02  Ampmo01  Ampne01  Ampne02  Ampno01  Ampol01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#         Ampov01  Amppa01  Amppe01     Amppe02  Amppo01  Amppo02  Amppr01  \
# 48228       NaN      NaN      NaN    2.500000      NaN      NaN      NaN
# 47256       NaN      NaN      NaN   11.547344      NaN      NaN      NaN
# 47024       NaN      NaN      NaN  217.500000      NaN      NaN      NaN
# 47237       NaN      NaN      NaN   31.400966      NaN      NaN      NaN
# 47042       NaN      NaN      NaN   14.150943      NaN      NaN      NaN
# ...         ...      ...      ...         ...      ...      ...      ...
# 48719       NaN      NaN      NaN   72.115385      NaN      NaN      NaN
# 48450  7.518797      NaN      NaN  102.756892      NaN      NaN      NaN
# 49198       NaN      NaN      NaN   63.451777      NaN      NaN      NaN
# 48775       NaN      NaN      NaN   36.496350      NaN      NaN      NaN
# 49200       NaN      NaN      NaN         NaN      NaN      NaN      NaN
#
#        Ampps01  Ampri01  Ampst01  Ampst02  Ampsu01  Ampsu02  Ampsu03  Ampsu04  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Amptu01  Ampve01  Ampve02  Ampvi01  Anaba01  Anemi01  Anetu01  Anoeu01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Anoga01  Anoin01  Anosp01  Astfo01  Aulal01  Aulam01  Aulbr01  Aulcr01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Aulcr02  Auldi01  Aulgr01  Aulis01  Aulit01  Aulli01  Aulni01  Aulpa01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Aulps01  Aulps02  Aulsu01  Aulsu02  Aulte01  Aulva01  Azpno01  Bacci01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#         Bacpa01  Bacul01  Berru01  Bible01  Birbi01  Brabr01  Braca01  \
# 48228       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...         ...      ...      ...      ...      ...      ...      ...
# 48719  9.615385      NaN      NaN      NaN      NaN      NaN      NaN
# 48450       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200       NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Brali01  Brane01  Brane02  Brapr01  Braps01  Breke01    Calae01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# ...        ...      ...      ...      ...      ...      ...        ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN   4.807692
# 48450      NaN      NaN      NaN      NaN      NaN      NaN  22.556391
# 49198      NaN      NaN      NaN      NaN      NaN      NaN  22.842640
# 48775      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN        NaN
#
#        Calae02  Calal01  Calau01   Calba01  Calbi01  Calfa01  Calfo01  \
# 48228      NaN      NaN      NaN       NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN       NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN       NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN  4.830918      NaN      NaN      NaN
# 47042      NaN      NaN      NaN       NaN      NaN      NaN      NaN
# ...        ...      ...      ...       ...      ...      ...      ...
# 48719      NaN      NaN      NaN       NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN       NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN       NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN       NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN       NaN      NaN      NaN      NaN
#
#        Calfo02  Calhy01  Calla01  Calla02  Calla03  Calle01  Calmi01  Calpa01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Calpu01  Calsc01  Calsi01  Caltr01  Calve01  Calwe01  Camcy01  Camhi01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Capcr01  Catad01  Cavpa01  Cenre01  Cergr01  Chaal01  Chabe01  Chafa01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Chamu01  Chare01  Charh01  Chasc01  Chath01  Clico01  Cliin01  Cocbr01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cocca01  Coccl01  Cocco01  Cocde01  Cocdi01  Cocdi02    Coceu01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN   7.500000
# 47256      NaN      NaN      NaN      NaN      NaN      NaN   4.618938
# 47024      NaN      NaN      NaN      NaN      2.5      NaN  77.500000
# 47237      NaN      NaN      NaN      NaN      NaN      NaN   4.830918
# 47042      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# ...        ...      ...      ...      ...      ...      ...        ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN   7.211538
# 48450      NaN      NaN      NaN      NaN      NaN      NaN        NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN  60.913706
# 48775      NaN      NaN      NaN      NaN      NaN      NaN  99.756691
# 49200      NaN      NaN      NaN      NaN      NaN      NaN  64.356436
#
#        Cocgr01  Cochu01  Cochu02  Cocin01  Cocla01  Cocle01  Cocli01  Cocme01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cocne01    Cocne02  Cocne03   Cocpa01    Cocpe01    Cocpl01  Cocps01  \
# 48228      NaN        NaN      NaN       NaN        NaN        NaN      NaN
# 47256      NaN        NaN      NaN       NaN        NaN        NaN      NaN
# 47024      NaN        NaN      NaN       NaN        NaN   5.000000      NaN
# 47237      NaN        NaN      NaN       NaN        NaN        NaN      NaN
# 47042      NaN        NaN      NaN       NaN        NaN        NaN      NaN
# ...        ...        ...      ...       ...        ...        ...      ...
# 48719      NaN        NaN      NaN       NaN        NaN   2.403846      NaN
# 48450      NaN        NaN      NaN       NaN  57.644110        NaN      NaN
# 49198      NaN  10.152284      NaN  5.076142  20.304569  35.532995      NaN
# 48775      NaN        NaN      NaN       NaN  41.362530   2.433090      NaN
# 49200      NaN        NaN      NaN       NaN        NaN        NaN      NaN
#
#        Cocps02  Cocre01  Cocro01  Cocsc01  Cocse01  Cocsu01  Conwe01  Cosco01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cosla01  Cosla02  Craac01  Craac02  Craha01  Crari01  Crasu01  Crasv01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN  24.3309      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cravi01  Crazi01  Creru01  Creth01  Ctepu01  Cycat01  Cycbo01  Cycco01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cyccy01  Cycde01  Cycde02  Cycdi01  Cycdu01  Cycex01  Cycgl01  Cycir01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cyckr01  Cycku01  Cycme01    Cycme02  Cycmi01  Cycop01  Cycpl01  \
# 48228      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# ...        ...      ...      ...        ...      ...      ...      ...
# 48719      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN  80.200501      NaN      NaN      NaN
# 49198      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN        NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN        NaN      NaN      NaN      NaN
#
#        Cycpl02  Cycps01  Cycsc01  Cycsc02  Cycst01  Cycst02  Cycst03  Cycst04  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cycsu01  Cycth01  Cycwo01  Cylgr01  Cymaf01    Cymaf02  Cymal01  \
# 48228      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# ...        ...      ...      ...      ...      ...        ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN  12.531328      NaN
# 49198      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN        NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN        NaN      NaN
#
#        Cymal02  Cymam01  Cyman01  Cyman02  Cyman03  Cyman04  Cymap01  Cymas01  \
# 48228      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47256      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47237      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 47042      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 48719      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48450      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49198      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 48775      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 49200      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        Cymbe01  Cymbi01  Cymbr01  Cymbu01  Cymci01   Cymco01  Cymcu01  \
# 48228      NaN      NaN      NaN      NaN      NaN  2.500000      NaN
# 47256      NaN      NaN      NaN      NaN      NaN       NaN      NaN
# 47024      NaN      NaN      NaN      NaN      NaN       NaN      NaN
# ...
# 49198              NaN              NaN              NaN              NaN
# 48775          0.00335          0.00335         0.009833         0.009833
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1470  Mean90Days_1473  Mean90Days_1476  Mean90Days_1480  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450         0.006500         0.000650          0.00335             0.02
# 49198              NaN              NaN              NaN              NaN
# 48775         0.009833         0.000883          0.00335             0.02
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1486  Mean90Days_1490  Mean90Days_1493  Mean90Days_1506  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450           0.0135           0.0135             3.35         0.020000
# 49198              NaN              NaN              NaN              NaN
# 48775           0.0135           0.0135             3.35         0.085333
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1517  Mean90Days_1522  Mean90Days_1524  Mean90Days_1537  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450          0.00335              NaN         0.003953          0.00335
# 49198              NaN              NaN              NaN              NaN
# 48775          0.00335              NaN         0.003350          0.00335
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1548  Mean90Days_1549  Mean90Days_1586  Mean90Days_1591  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450         0.006500         0.013500           0.0065         0.013500
# 49198              NaN              NaN              NaN              NaN
# 48775         0.009833         0.020167           0.0065         0.020167
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1592  Mean90Days_1593  Mean90Days_1621  Mean90Days_1622  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450         0.013500         0.013500          0.00065          0.00335
# 49198              NaN              NaN              NaN              NaN
# 48775         0.020167         0.020167          0.00065          0.00335
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1623  Mean90Days_1629  Mean90Days_1630  Mean90Days_1642  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450          0.00335           0.0335           0.0335              NaN
# 49198              NaN              NaN              NaN              NaN
# 48775          0.00335           0.0335           0.0335              NaN
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1643  Mean90Days_1644  Mean90Days_1645  Mean90Days_1646  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450              NaN              NaN         0.006500              NaN
# 49198              NaN              NaN              NaN              NaN
# 48775              NaN              NaN         0.009833              NaN
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1647  Mean90Days_1648  Mean90Days_1649  Mean90Days_1652  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450         0.006500              NaN           0.0135           0.0135
# 49198              NaN              NaN              NaN              NaN
# 48775         0.009833              NaN           0.0135           0.0135
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1666  Mean90Days_1669  Mean90Days_1688  Mean90Days_1694  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN         0.029000              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450          0.00335          0.00335         0.000650          0.00335
# 49198              NaN              NaN              NaN              NaN
# 48775          0.00335          0.00335         0.000883          0.00335
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1699  Mean90Days_1700  Mean90Days_1723  Mean90Days_1743  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450              NaN           0.0065              NaN              NaN
# 49198              NaN              NaN              NaN              NaN
# 48775             0.02           0.0065              NaN              NaN
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1770  Mean90Days_1777  Mean90Days_1780  Mean90Days_1811  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450              NaN              NaN              NaN              NaN
# 49198              NaN              NaN              NaN              NaN
# 48775              NaN              NaN              NaN              NaN
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1841  Mean90Days_1911  Mean90Days_1955  Mean90Days_1958  \
# 48228         1.700000              NaN              NaN              NaN
# 47256         4.000000              NaN              NaN              NaN
# 47024         8.500000              NaN              NaN              NaN
# 47237         3.033333              NaN              NaN              NaN
# 47042         3.350000              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719         1.800000              NaN              NaN              NaN
# 48450         2.300000           0.0065         0.100000            0.065
# 49198         1.300000              NaN              NaN              NaN
# 48775         2.000000           0.0065         0.133333            0.065
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_1959  Mean90Days_1975  Mean90Days_2539  Mean90Days_2872  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450             0.02           0.0135            0.065          0.00335
# 49198              NaN              NaN              NaN              NaN
# 48775             0.02           0.0135            0.065          0.00335
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_2879  Mean90Days_2904  Mean90Days_2923  Mean90Days_2925  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450         0.000065              NaN              NaN              NaN
# 49198              NaN              NaN              NaN              NaN
# 48775         0.000065              NaN              NaN              NaN
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_3336  Mean90Days_5275  Mean90Days_5474  Mean90Days_5986  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450              NaN              NaN            0.065            0.001
# 49198              NaN              NaN              NaN              NaN
# 48775              NaN              NaN            0.065            0.001
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_6249  Mean90Days_6372  Mean90Days_6598  Mean90Days_6600  \
# 48228              NaN              NaN              NaN              NaN
# 47256              NaN              NaN              NaN              NaN
# 47024              NaN              NaN              NaN              NaN
# 47237              NaN              NaN              NaN              NaN
# 47042              NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 48719              NaN              NaN              NaN              NaN
# 48450              NaN         0.000395              NaN              NaN
# 49198              NaN              NaN              NaN              NaN
# 48775              NaN         0.000395              NaN              NaN
# 49200              NaN              NaN              NaN              NaN
#
#        Mean90Days_7074  Mean90Days_XOMP  IBD  IBD_pred_raw  IBD_pred_corr
# 48228              NaN              NaN  NaN     22.543489      20.000000
# 47256              NaN              NaN  NaN      8.558726       8.558726
# 47024              NaN              NaN  NaN     14.376057      14.376057
# 47237              NaN              NaN  NaN     10.407555      10.407555
# 47042              NaN              NaN  NaN     14.643012      14.643012
# ...                ...              ...  ...           ...            ...
# 48719              NaN              NaN  NaN     14.733236      14.733236
# 48450          0.00026           0.1635  NaN     17.484596      17.484596
# 49198              NaN              NaN  NaN     18.234404      18.234404
# 48775          0.00026           0.1635  NaN     13.434991      13.434991
# 49200              NaN              NaN  NaN     20.369392      20.007978
#
# [5663 rows x 2853 columns]

# %%
scored_df = scored_df[['SamplingOperations_code','IBD_pred_corr']]
# rename IBD_pred to IBD_EQR_Status
scored_df.rename(columns={'IBD_pred':'IBD_EQR_Status'}, inplace=True)
# Out:
# C:\Users\herie\AppData\Local\Temp\ipykernel_16360\1338188445.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scored_df.rename(columns={'IBD_pred':'IBD_EQR_Status'}, inplace=True)

# %%
scored_df.to_csv(f'results/015_Catboost2/015_Catboost2_TPEPM{name}.csv', index=False)

# %%
# save the model joblib
import joblib
joblib.dump(model, f'results/015_Catboost2/015_Catboost2_TPEPM{name}.joblib', compress=3)
# Out:
# ['results/015_Catboost2/015_Catboost2_TPEPMTruncated.joblib']
