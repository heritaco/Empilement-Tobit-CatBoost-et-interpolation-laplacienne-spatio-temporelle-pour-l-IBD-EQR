# %%
import requests

BASE_URL = "https://datathon.digitalizados.mx/"
TEAM_KEY = "CAJY-QU4X-7A4T"

# %%
r = requests.get(f"{BASE_URL}/health", timeout=10)
r.status_code, r.json()
# Out:
# (200, {'status': 'ok'})

# %%
import pandas as pd

# read example submission
FILE_NAME = "results/001_un_lolazo/un_lolazo_submission.csv"
read_example = pd.read_csv(FILE_NAME)
read_example
# Out:
#      SamplingOperations_code IBD_EQR_Status
# 0         S02000010_20080811       Moderate
# 1         S02000010_20100719           Good
# 2         S02000010_20150811       Moderate
# 3         S02000010_20170703           Good
# 4         S02000011_20100719           Good
# ...                      ...            ...
# 5058      S06940940_20100708       Moderate
# 5059      S06940940_20230623       Moderate
# 5060      S06960950_20160629           High
# 5061      S06960950_20180719           High
# 5062      S06970900_20150601           High
#
# [5063 rows x 2 columns]

# %%
#    Asegúrate de que tu CSV tenga encabezados: SamplingOperations_code,IBD_EQR_Status
with open(FILE_NAME, "rb") as f:
    files = {"file": (FILE_NAME, f, "text/csv")}
    data = {"team_key": TEAM_KEY}
    r = requests.post(f"{BASE_URL}/submit", data=data, files=files, timeout=30)

print("submit:", r.status_code, r.text)
# Out:
# submit: 200 {"status":"ok","accuracy":0.814142,"n_correct":4122,"n_total":5063,"daily_limit":2,"used_today":1,"remaining_today":1}
