# %%
import requests

BASE_URL = "https://datathon.digitalizados.mx/"
TEAM_KEY = "CAJY-QU4X-7A4T"

# %%
r = requests.get(f"{BASE_URL}/health", timeout=10)
r.status_code, r.json()
# Out:
# (200, {'status': 'ok'})

# %%
import pandas as pd

# read example submission
FILE_NAME = "results/compare/Catboost_Classification.csv"
read_example = pd.read_csv(FILE_NAME)
read_example
# Out:
#      SamplingOperations_code IBD_EQR_Status
# 0         S05169000_20130911           High
# 1         S05169000_20200819           High
# 2         S05172000_20210813           Good
# 3         S05172050_20210824           Good
# 4         S05172350_20120827           High
# ...                      ...            ...
# 5658      S03128500_20120723       Moderate
# 5659      S03128640_20130718       Moderate
# 5660      S03128640_20181011       Moderate
# 5661      S03128732_20210817           Good
# 5662      S03129170_20150630           High
#
# [5663 rows x 2 columns]

# %%
#    Asegúrate de que tu CSV tenga encabezados: SamplingOperations_code,IBD_EQR_Status
with open(FILE_NAME, "rb") as f:
    files = {"file": (FILE_NAME, f, "text/csv")}
    data = {"team_key": TEAM_KEY}
    r = requests.post(f"{BASE_URL}/submit", data=data, files=files, timeout=30)

print("submit:", r.status_code, r.text)
# Out:
# submit: 200 {"status":"ok","accuracy":0.833695,"n_correct":4221,"n_total":5063,"daily_limit":2,"used_today":2,"remaining_today":0}
